# %%
class Test:

    def __str__(self):
        return "i am object"


a = Test()  # creating the object
# print(a)


class Test2:
    x = 11

    def __str__(self):
        return f"value of x is {self.x}"


obj = Test2()
# print(obj)


class Test3:

    def __init__(self):
        self.a = 10
        self.b = 11

    def __str__(self) -> str:
        return f"{self.a, self.b}"


obj = Test3()


class Test4:
    def __init__(self, a, b, c):
        self.x = a
        self.y = b
        self.z = c

obj = Test4(1,3,4)
# print(obj)


class Test5():
    def __init__(self, a, b, c):
        self.x = a
        self.y = b
        self.z = c
    
    def __str__(self):
        return f'hi broadway i am  return function'

    def testfunction(self):
        return f'testfunction class {self.x}'

obj = Test5(1,3,4)

# print(obj.testfunction())


class Test6():
    def __init__(self):
        self.a = 10
        self.b = 11

    def add(self):
        return self.a + self.b

    def sub(self):
        # return self.add()
        return self.a - self.b

obj = Test6()

sum_of_number = obj.add()
differce_of_number = obj.sub()
print(sum_of_number)
print(differce_of_number)
# Out:
# 21
# -1
